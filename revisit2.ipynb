# %%
x = 5
y = 3
print(x & y)
# Out:
# 1

# %%
a = 3 
b = 4.3
c = 4 + 5j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
t = "the world is yours"
print(type(t))
print(t[0])
print(t[-1])
# Out:
# <class 'str'>
# t
# s

# %%
a = [1, 2, 6]
print(a)
# Out:
# [1, 2, 6]

# %%
a = ["the", "world", "is", "yours", 4, 7]
print(a[1])
print(a[-4])
# Out:
# world
# is

# %%
a = ["the", "world", "is", "yours", 4, 7]
print(a[1:3])
# Out:
# ['world', 'is']

# %%
d = {1:'the', 2:'world', 3:'is', 4:'yours'}
print(d)
print(d[1])
print(d.get(1))
# Out:
# {1: 'the', 2: 'world', 3: 'is', 4: 'yours'}
# the
# the
