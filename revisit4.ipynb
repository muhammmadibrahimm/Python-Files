# %%
for i in range(8):
    print("al pacino", i)
# Out:
# al pacino 0
# al pacino 1
# al pacino 2
# al pacino 3
# al pacino 4
# al pacino 5
# al pacino 6
# al pacino 7

# %%
actors = ['leo', 'de niro', 'al pacino']
for i in actors:
    print(actors)
# Out:
# ['leo', 'de niro', 'al pacino']
# ['leo', 'de niro', 'al pacino']
# ['leo', 'de niro', 'al pacino']

# %%
actors = ['leo', 'de niro', 'al pacino']
for i in actors:
    print(i)
# Out:
# leo
# de niro
# al pacino

# %%
lst1 = [1,2,3,4,5]
lst2 = [6,7,8,9,10]
lst3 = []
for i in zip(lst1, lst2):
    lst3.append(sum(i))
    print(lst3)
# Out:
# [7]
# [7, 9]
# [7, 9, 11]
# [7, 9, 11, 13]
# [7, 9, 11, 13, 15]

# %%
actors = ['leo', 'de niro', 'al pacino', 'bale', 'ryan', 'chalamet']
for i in range(3):
    print(i, actors[i])
# Out:
# 0 leo
# 1 de niro
# 2 al pacino

# %%
for i in actors[::-1]:
    print(i)
# Out:
# chalamet
# ryan
# bale
# al pacino
# de niro
# leo

# %%
actors
# Out:
# ['leo', 'de niro', 'al pacino', 'bale', 'ryan', 'chalamet']

# %%
for i in actors:
    if len(i) <= 4:
        print(f"{i} allowed")
    else:
        print(f"{i} not allowed")
# Out:
# leo allowed
# de niro not allowed
# al pacino not allowed
# bale allowed
# ryan allowed
# chalamet not allowed
