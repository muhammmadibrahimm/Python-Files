# %% [markdown]
# # multiple inputs at once

# %%
x, y = input("Enter Numbers:").split()
print(x, y)
# Out:
# Enter Numbers: 14, 15
# 14, 15

# %%
i = input("Age")
f = float(input("evaluate"))
print(i, f)
# Out:
# Age 21
# evaluate 3.2
# 21 3.2

# %%
x = 5
y = x
y = y + 1
print(x)
print(y)
# Out:
# 5
# 6

# %%
x = 10
del x

# %% [markdown]
# ### swappin two variables

# %%
a, b = 5, 7
a, b = b, a
print(a, b)
# Out:
# 7 5

# %%
word = "Python"
length = len(word)
print(length)
# Out:
# 6

# %%
a = 6
b = 3
print("add:", a + b)
print("sub:", a - b)
print("div:", a / b)
print("mul:", a * b)
print("mod:", a % b)
print("floor:", a // b)
print("exp:", a ** b)
# Out:
# add: 9
# sub: 3
# div: 2.0
# mul: 18
# mod: 0
# floor: 2
# exp: 216

# %%
a = 6
b = 3
print(a < b)
print(a > b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# True
# False
